# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
df = pd.read_csv('./DRIVE/Sb3 Files/SB3_FILES1_CSV/main.csv')

# %%
df.head()
# Out:
#    url                                  filename  points  Abstraction  \
# 0  NaN                           birdygethem.sb3      18            1
# 1  NaN                GAME SUMMERS TIRABASSI.sb3      19            1
# 2  NaN                     Cloud collectors .sb3      15            1
# 3  NaN                        ocean climate .sb3      12            0
# 4  NaN  Deforestation Hailey and Remi_s Game.sb3      25            1
#
#    Parallelism  Logic  Synchronization  Flow control  User interactivity  \
# 0            1      1                2             4                   1
# 1            2      1                2             2                   4
# 2            1      1                2             2                   2
# 3            0      2                0             1                   2
# 4            4      2                3             2                   3
#
#    Data representation  ...  Error  dashboard_mode  Van points  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   url                      0 non-null      float64
#  1   filename                 193 non-null    object
#  2   points                   193 non-null    int64
#  3   Abstraction              193 non-null    int64
#  4   Parallelism              193 non-null    int64
#  5   Logic                    193 non-null    int64
#  6   Synchronization          193 non-null    int64
#  7   Flow control             193 non-null    int64
#  8   User interactivity       193 non-null    int64
#  9   Data representation      193 non-null    int64
#  10  Math operators           193 non-null    int64
#  11  Motion operators         193 non-null    int64
#  12  DuplicateScripts         193 non-null    int64
#  13  DeadCode                 193 non-null    int64
# ...

# %%
df.describe()
# Out:
#        url      points  Abstraction  Parallelism       Logic  Synchronization  \
# count  0.0  193.000000   193.000000   193.000000  193.000000       193.000000
# mean   NaN   20.963731     1.549223     3.041451    1.523316         2.606218
# std    NaN    5.311518     1.040288     1.265875    1.254461         0.924416
# min    NaN    0.000000     0.000000     0.000000    0.000000         0.000000
# 25%    NaN   18.000000     1.000000     2.000000    1.000000         2.000000
# 50%    NaN   21.000000     1.000000     4.000000    1.000000         3.000000
# 75%    NaN   24.000000     2.000000     4.000000    1.000000         3.000000
# max    NaN   34.000000     4.000000     4.000000    4.000000         4.000000
#
#        Flow control  User interactivity  Data representation  Math operators  \
# count    193.000000          193.000000           193.000000      193.000000
# mean       2.388601            2.212435             3.404145        1.580311
# ...

# %%
df['points']
# Out:
# 0      18
# 1      19
# 2      15
# 3      12
# 4      25
#        ..
# 188    29
# 189    13
# 190    21
# 191    24
# 192    19
# Name: points, Length: 193, dtype: int64

# %%
df[['points','Abstraction']]
# Out:
#      points  Abstraction
# 0        18            1
# 1        19            1
# 2        15            1
# 3        12            0
# 4        25            1
# ..      ...          ...
# 188      29            3
# 189      13            1
# 190      21            4
# 191      24            1
# 192      19            1
#
# [193 rows x 2 columns]

# %%
print(df.loc[0])
# Out:
# url                                    NaN
# filename                   birdygethem.sb3
# points                                  18
# Abstraction                              1
# Parallelism                              1
# Logic                                    1
# Synchronization                          2
# Flow control                             4
# User interactivity                       1
# Data representation                      4
# Math operators                           2
# Motion operators                         2
# DuplicateScripts                         0
# DeadCode                                 1
# SpriteNaming                             0
# BackdropNaming                           0
# Error                                  NaN
# dashboard_mode                     Default
# Van points                              12
# Van Abstraction                          1
# Van Parallelism                          1
# Van Logic                                1
# ...

# %%
print(df.iloc[0])
# Out:
# url                                    NaN
# filename                   birdygethem.sb3
# points                                  18
# Abstraction                              1
# Parallelism                              1
# Logic                                    1
# Synchronization                          2
# Flow control                             4
# User interactivity                       1
# Data representation                      4
# Math operators                           2
# Motion operators                         2
# DuplicateScripts                         0
# DeadCode                                 1
# SpriteNaming                             0
# BackdropNaming                           0
# Error                                  NaN
# dashboard_mode                     Default
# Van points                              12
# Van Abstraction                          1
# Van Parallelism                          1
# Van Logic                                1
# ...

# %%
df[df['points']>10]
# Out:
#      url                                  filename  points  Abstraction  \
# 0    NaN                           birdygethem.sb3      18            1
# 1    NaN                GAME SUMMERS TIRABASSI.sb3      19            1
# 2    NaN                     Cloud collectors .sb3      15            1
# 3    NaN                        ocean climate .sb3      12            0
# 4    NaN  Deforestation Hailey and Remi_s Game.sb3      25            1
# ..   ...                                       ...     ...          ...
# 188  NaN                  Cycle of Consumerism.sb3      29            3
# 189  NaN                     Save the Trees!!!.sb3      13            1
# 190  NaN                          kill the CO2.sb3      21            4
# 191  NaN              Global Warming_ The Game.sb3      24            1
# 192  NaN          Scuba dive to save the world.sb3      19            1
#
#      Parallelism  Logic  Synchronization  Flow control  User interactivity  \
# ...

# %%
df['points']>10
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 188    True
# 189    True
# 190    True
# 191    True
# 192    True
# Name: points, Length: 193, dtype: bool

# %%
df[df['points']>10]
# Out:
#      url                                  filename  points  Abstraction  \
# 0    NaN                           birdygethem.sb3      18            1
# 1    NaN                GAME SUMMERS TIRABASSI.sb3      19            1
# 2    NaN                     Cloud collectors .sb3      15            1
# 3    NaN                        ocean climate .sb3      12            0
# 4    NaN  Deforestation Hailey and Remi_s Game.sb3      25            1
# ..   ...                                       ...     ...          ...
# 188  NaN                  Cycle of Consumerism.sb3      29            3
# 189  NaN                     Save the Trees!!!.sb3      13            1
# 190  NaN                          kill the CO2.sb3      21            4
# 191  NaN              Global Warming_ The Game.sb3      24            1
# 192  NaN          Scuba dive to save the world.sb3      19            1
#
#      Parallelism  Logic  Synchronization  Flow control  User interactivity  \
# ...

# %%
grouped = df.groupby('points')

# %%
print(grouped.get_group(18))
# Out:
#      url                                  filename  points  Abstraction  \
# 0    NaN                           birdygethem.sb3      18            1
# 7    NaN                        Albedo Project.sb3      18            1
# 21   NaN             Scratch Trivia Game remix.sb3      18            1
# 22   NaN                        SpAcE pOnG (1).sb3      18            3
# 26   NaN          Leyla and Erin-3 remix remix.sb3      18            1
# 53   NaN               Climate Change Game (1).sb3      18            1
# 68   NaN                         Penguin Game .sb3      18            1
# 97   NaN                         sean and josh.sb3      18            1
# 130  NaN                            SpAcE pOnG.sb3      18            3
# 135  NaN                      Catch the Monkey.sb3      18            1
# 147  NaN  Reduce dat boi Co2 in the Atmosphere.sb3      18            1
# 159  NaN                       Save the City! .sb3      18            1
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, marker='o', linestyle='-', color='b', label='Línea 1')
plt.title('Gráfico de Línea')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.legend()  # Mostrar leyenda
plt.grid(True)  # Mostrar cuadrícula
plt.tight_layout()  # Ajustar diseño
plt.show()

# %%
# Datos
categorias = ['A', 'B', 'C', 'D']
valores = [20, 35, 30, 25]

# Crear el gráfico de barras
plt.figure(figsize=(8, 5))  # Tamaño opcional de la figura
plt.bar(categorias, valores, color='g')

# Personalizar el gráfico
plt.title('Gráfico de Barras')
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.grid(axis='y')  # Mostrar cuadrícula en el eje Y
plt.tight_layout()  # Ajustar diseño

# Mostrar el gráfico
plt.show()

# %%
categorias = ['A', 'B', 'C', 'D', 'E']
valores = [4, 3, 2, 5, 4]

num_vars = len(categorias)
angulos = [n * 2 * np.pi / num_vars for n in range(num_vars)]
angulos += angulos[:1]
valores += valores[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angulos, valores, color='b', linewidth=2)  
ax.set_rlabel_position(0)  

ax.set_xticks(angulos[:-1])
ax.set_xticklabels(categorias)

# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
dimensions = df.columns[1:9]


categorias = ['A', 'B', 'C', 'D', 'E']
valores = [4, 3, 2, 5, 4]

num_vars = len(categorias)
angulos = [n * 2 * np.pi / num_vars for n in range(num_vars)]
angulos += angulos[:1]
valores += valores[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angulos, valores, color='b', linewidth=2)  
ax.set_rlabel_position(0)  

ax.set_xticks(angulos[:-1])
ax.set_xticklabels(dimensions)

# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 16
#      13 ax.set_rlabel_position(0)
#      15 ax.set_xticks(angulos[:-1])
# ---> 16 ax.set_xticklabels(dimensions)
#      18 # Ajustar el diseño
#      19 plt.tight_layout()
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/matplotlib/axis.py:2062, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2058 elif isinstance(locator, mticker.FixedLocator):
#    2059     # Passing [] as a list of labels is often used as a way to
#    2060     # remove all tick labels, so only error for > 0 labels
# ...

# %%
cur_df = "./DRIVE/Sb3 Files/SB3_FILES1_CSV/main.csv"
df = pd.read_csv(cur_df)

# DATA PREPROCESSING
dims = df.iloc[:, 3:12]
dims_names = dims.columns.tolist()
dim_means = dims.mean()
dim_means = dim_means.tolist()
dim_means = [round(n,2) for n in dim_means]

# ADAPTIONS TO GRAPH NAMES
cat = dims_names
val = dim_means

# GRAPH
num_vars = len(cat)
angles = [n * 2 * np.pi / num_vars for n in range(num_vars)]
angles += angles[:1]
val += val[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angles, val, color='b', linewidth=2)  
ax.set_rlabel_position(0)  

# DESIGN
plt.title(cur_df, fontsize=16, color='blue')
ax.set_xticks(angles[:-1])
ax.set_xticklabels(dimensions)

# ADJUST DESIGN
plt.tight_layout()

# SHOW GRAPH
plt.show()
